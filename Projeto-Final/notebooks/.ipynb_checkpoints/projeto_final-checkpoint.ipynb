# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefa II
#
# Neste projeto, estamos construindo um credit scoring para cartão de crédito, em um desenho amostral com 15 safras, e utilizando 12 meses de performance.
#
# Carregue a base de dados ```credit_scoring.ftr```.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import statsmodels.formula.api as smf
import statsmodels.api as sm

from sklearn import metrics
from scipy.stats import ks_2samp
from scipy.stats import t

from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

# %%
data = pd.read_feather('../data/credit_scoring.ftr')
data['mau'] = data.mau.astype('int64')
data = data.sample(50000)

# %% [markdown]
# ## Amostragem
#
# Separe os três últimos meses como safras de validação *out of time* (oot).
#
# Variáveis:<br>
# Considere que a variável ```data_ref``` não é uma variável explicativa, é somente uma variável indicadora da safra, e não deve ser utilizada na modelagem. A variávei ```index``` é um identificador do cliente, e também não deve ser utilizada como covariável (variável explicativa). As restantes podem ser utilizadas para prever a inadimplência, incluindo a renda.

# %%
df_oot = data.copy().query("data_ref >= '2016-01-01'")
df = data.copy().query("data_ref < '2016-01-01'")

variaveis = ['sexo', 'posse_de_veiculo', 'posse_de_imovel',
       'qtd_filhos', 'tipo_renda', 'educacao', 'estado_civil',
       'tipo_residencia', 'idade', 'tempo_emprego', 'qt_pessoas_residencia',
       'renda', 'mau']

# %%
def IV(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    rótulo_evento = tab.columns[0]
    rótulo_nao_evento = tab.columns[1]

    tab['pct_evento'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    tab['ep'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    
    tab['pct_nao_evento'] = tab[rótulo_nao_evento]/tab.loc['total',rótulo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab['iv_parcial'].sum()

# %%
metadados = pd.DataFrame(df[variaveis].dtypes, columns=['dtype'])
metadados['nmissing'] = df.isna().sum()
metadados['valores_unicos'] = df.nunique()
metadados['papel'] = 'covariavel'
metadados.loc['mau','papel'] = 'resposta'
metadados.loc['bom','papel'] = 'resposta'

for var in metadados[metadados.papel=='covariavel'].index:
    if  (metadados.loc[var, 'valores_unicos']>6):
        metadados.loc[var, 'IV'] = IV(pd.qcut(df[var],5,duplicates='drop'), df.mau)
    else: 
        metadados.loc[var, 'IV'] = IV(df[var], df.mau)

metadados
# Out:
#                          dtype  nmissing  valores_unicos       papel        IV
# sexo                    object       0.0             2.0  covariavel  0.002367
# posse_de_veiculo        object       0.0             2.0  covariavel  0.001074
# posse_de_imovel         object       0.0             2.0  covariavel  0.007228
# qtd_filhos               int64       0.0             8.0  covariavel  0.000095
# tipo_renda              object       0.0             5.0  covariavel       inf
# educacao                object       0.0             5.0  covariavel  0.005935
# estado_civil            object       0.0             5.0  covariavel  0.002943
# tipo_residencia         object       0.0             6.0  covariavel  0.007085
# idade                    int64       0.0            47.0  covariavel  0.009294
# tempo_emprego          float64    6702.0          2929.0  covariavel  0.317127
# qt_pessoas_residencia  float64       0.0             9.0  covariavel  0.002194
# renda                  float64       0.0         33351.0  covariavel  0.862857
# mau                      int64       0.0             2.0    resposta       NaN
# bom                        NaN       NaN             NaN    resposta       NaN

# %% [markdown]
# ## Descritiva básica univariada
#
# - Descreva a base quanto ao número de linhas, número de linhas para cada mês em ```data_ref```.
# - Faça uma descritiva básica univariada de cada variável. Considere as naturezas diferentes: qualitativas e quantitativas.

# %%
df.groupby('data_ref').count()
# Out:
#             index  sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# data_ref
# 2015-01-01   3322  3322              3322             3322        3322
# 2015-02-01   3300  3300              3300             3300        3300
# 2015-03-01   3344  3344              3344             3344        3344
# 2015-04-01   3357  3357              3357             3357        3357
# 2015-05-01   3311  3311              3311             3311        3311
# 2015-06-01   3239  3239              3239             3239        3239
# 2015-07-01   3410  3410              3410             3410        3410
# 2015-08-01   3384  3384              3384             3384        3384
# 2015-09-01   3336  3336              3336             3336        3336
# 2015-10-01   3280  3280              3280             3280        3280
# 2015-11-01   3370  3370              3370             3370        3370
# 2015-12-01   3368  3368              3368             3368        3368
#
#             tipo_renda  educacao  estado_civil  tipo_residencia  idade  \
# data_ref
# 2015-01-01        3322      3322          3322             3322   3322
# 2015-02-01        3300      3300          3300             3300   3300
# 2015-03-01        3344      3344          3344             3344   3344
# 2015-04-01        3357      3357          3357             3357   3357
# 2015-05-01        3311      3311          3311             3311   3311
# 2015-06-01        3239      3239          3239             3239   3239
# 2015-07-01        3410      3410          3410             3410   3410
# 2015-08-01        3384      3384          3384             3384   3384
# 2015-09-01        3336      3336          3336             3336   3336
# 2015-10-01        3280      3280          3280             3280   3280
# 2015-11-01        3370      3370          3370             3370   3370
# 2015-12-01        3368      3368          3368             3368   3368
#
#             tempo_emprego  qt_pessoas_residencia  renda   mau
# data_ref
# 2015-01-01           2773                   3322   3322  3322
# 2015-02-01           2742                   3300   3300  3300
# 2015-03-01           2775                   3344   3344  3344
# 2015-04-01           2768                   3357   3357  3357
# 2015-05-01           2793                   3311   3311  3311
# 2015-06-01           2722                   3239   3239  3239
# 2015-07-01           2828                   3410   3410  3410
# 2015-08-01           2820                   3384   3384  3384
# 2015-09-01           2774                   3336   3336  3336
# 2015-10-01           2720                   3280   3280  3280
# 2015-11-01           2810                   3370   3370  3370
# 2015-12-01           2794                   3368   3368  3368

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(16, 6))
continuas = ['idade', 'qt_pessoas_residencia', 'qtd_filhos', 'tempo_emprego', 'renda']
for i, var in enumerate(continuas):
    sns.boxplot(ax=axes[i], x=df[var])

# %%
df = df.query('renda < 50000')
df_oot = df_oot.query('renda < 50000')

fig, ax = plt.subplots(figsize=(16, 3))
sns.boxplot(ax=ax, x=df['renda'])
# Out:
# <Axes: xlabel='renda'>

# %%
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(16, 16))
discretas = [var for var in variaveis if var not in continuas]


for i, var in enumerate(discretas):
    sns.histplot(ax=axes[i//2][i%2], x=df[var], binwidth=.5, discrete=True, shrink=.8)

# %% [markdown]
# ## Descritiva bivariada
#
# Faça uma análise descritiva bivariada de cada variável

# %%
def biv_discreta(var, df):
    df['bom'] = 1-df.mau
    g = df.groupby(var)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g['mau'].mean().index, 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]
    ax[0].set_xlim([-.3, num_cat-.7])

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[0].set_xticks(list(range(num_cat)))
    ax[0].set_xticklabels(biv[var], rotation=15)
    
    ax[1] = biv.cont.plot.bar()
    
    return display(biv)


def biv_continua(var, ncat, df):
    df['bom'] = 1-df.mau
    cat_srs, bins = pd.qcut(df[var], ncat, retbins=True, precision=0, duplicates='drop')
    g = df.groupby(cat_srs)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g[var].mean(), 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[1] = biv.cont.plot.bar()
    return display(biv)

# %%
biv_discreta(discretas[0], df);
# Out:
#       qt_bom  qt_mau       mau sexo   cont        ep   mau_sup   mau_inf  \
# sexo
# F      22304    1695  0.070628    F  23999  0.001654  0.073870  0.067386
# M      11412     742  0.061050    M  12154  0.002172  0.065307  0.056793
#
#          logit  logit_sup  logit_inf       woe   woe_sup   woe_inf
# sexo
# F    -2.577083  -2.528715  -2.627548  0.050121  0.098490 -0.000344
# M    -2.733071  -2.661123  -2.809874 -0.105867 -0.033918 -0.182669

# %%
biv_discreta(discretas[1], df);
# Out:
#                   qt_bom  qt_mau       mau posse_de_veiculo   cont        ep  \
# posse_de_veiculo
# N                  20397    1525  0.069565                N  21922  0.001718
# S                  13319     912  0.064085                S  14231  0.002053
#
#                    mau_sup   mau_inf     logit  logit_sup  logit_inf  \
# posse_de_veiculo
# N                 0.072933  0.066197 -2.593393  -2.542488  -2.646633
# S                 0.068110  0.060061 -2.681307  -2.616098  -2.750448
#
#                        woe   woe_sup   woe_inf
# posse_de_veiculo
# N                 0.033811  0.084717 -0.019428
# S                -0.054102  0.011106 -0.123243

# %%
biv_discreta(discretas[2], df);
# Out:
#                  qt_bom  qt_mau       mau posse_de_imovel   cont        ep  \
# posse_de_imovel
# N                 11176     902  0.074681               N  12078  0.002392
# S                 22540    1535  0.063759               S  24075  0.001575
#
#                   mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# posse_de_imovel
# N                0.079370  0.069993 -2.516909  -2.450940  -2.586803  0.110295
# S                0.066845  0.060673 -2.686761  -2.636187  -2.739670 -0.059556
#
#                   woe_sup   woe_inf
# posse_de_imovel
# N                0.176265  0.040402
# S               -0.008982 -0.112466

# %%
biv_discreta(discretas[3], df);
# Out:
# D:\Python-Venvs\win-data-science\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# D:\Python-Venvs\win-data-science\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# D:\Python-Venvs\win-data-science\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#                   qt_bom  qt_mau       mau        tipo_renda   cont        ep  \
# tipo_renda
# Assalariado        17233    1294  0.069844       Assalariado  18527  0.001873
# Bolsista              12       0  0.000000          Bolsista     12  0.000000
# Empresário          7762     543  0.065382        Empresário   8305  0.002713
# Pensionista         6172     439  0.066404       Pensionista   6611  0.003062
# Servidor público    2537     161  0.059674  Servidor público   2698  0.004560
#
#                    mau_sup   mau_inf     logit  logit_sup  logit_inf  \
# tipo_renda
# Assalariado       0.073514  0.066174 -2.589088  -2.533917  -2.647009
# Bolsista          0.000000  0.000000      -inf       -inf       -inf
# Empresário        0.070700  0.060065 -2.659886  -2.575993  -2.750383
# Pensionista       0.072408  0.060401 -2.643279  -2.550282  -2.744440
# Servidor público  0.068616  0.050731 -2.757333  -2.608143  -2.929146
#
#                        woe   woe_sup   woe_inf
# tipo_renda
# Assalariado       0.038117  0.093288 -0.019804
# Bolsista              -inf      -inf      -inf
# Empresário       -0.032681  0.051212 -0.123178
# Pensionista      -0.016074  0.076923 -0.117235
# Servidor público -0.130128  0.019062 -0.301941

# %%
df2 = df.copy()
df_oot2 = df_oot.copy()
df2.tipo_renda.replace({'Assalariado': 'Assalariado/Bolsista', 'Bolsista': 'Assalariado/Bolsista'}, inplace=True)
df_oot2.tipo_renda.replace({'Assalariado': 'Assalariado/Bolsista', 'Bolsista': 'Assalariado/Bolsista'}, inplace=True)
biv_discreta('tipo_renda', df2)
# Out:
#                       qt_bom  qt_mau       mau            tipo_renda   cont  \
# tipo_renda
# Assalariado/Bolsista   17245    1294  0.069799  Assalariado/Bolsista  18539
# Empresário              7762     543  0.065382            Empresário   8305
# Pensionista             6172     439  0.066404           Pensionista   6611
# Servidor público        2537     161  0.059674      Servidor público   2698
#
#                             ep   mau_sup   mau_inf     logit  logit_sup  \
# tipo_renda
# Assalariado/Bolsista  0.001871  0.073467  0.066131 -2.589784  -2.534614
# Empresário            0.002713  0.070700  0.060065 -2.659886  -2.575993
# Pensionista           0.003062  0.072408  0.060401 -2.643279  -2.550282
# Servidor público      0.004560  0.068616  0.050731 -2.757333  -2.608143
#
#                       logit_inf       woe   woe_sup   woe_inf
# tipo_renda
# Assalariado/Bolsista  -2.647704  0.037421  0.092591 -0.020499
# Empresário            -2.750383 -0.032681  0.051212 -0.123178
# Pensionista           -2.744440 -0.016074  0.076923 -0.117235
# Servidor público      -2.929146 -0.130128  0.019062 -0.301941

# %%
biv_discreta(discretas[4], df);
# Out:
#                      qt_bom  qt_mau       mau             educacao   cont  \
# educacao
# Fundamental             397      44  0.099773          Fundamental    441
# Médio                 22705    1658  0.068054                Médio  24363
# Pós graduação            40       5  0.111111        Pós graduação     45
# Superior completo      9200     627  0.063804    Superior completo   9827
# Superior incompleto    1374     103  0.069736  Superior incompleto   1477
#
#                            ep   mau_sup   mau_inf     logit  logit_sup  \
# educacao
# Fundamental          0.014271  0.127822  0.071725 -2.199747  -1.920358
# Médio                0.001613  0.071216  0.064892 -2.616973  -2.568151
# Pós graduação        0.046849  0.205528  0.016694 -2.079442  -1.352094
# Superior completo    0.002465  0.068637  0.058971 -2.686012  -2.607824
# Superior incompleto  0.006627  0.082736  0.056736 -2.590752  -2.405740
#
#                      logit_inf       woe   woe_sup   woe_inf
# educacao
# Fundamental          -2.560491  0.427458  0.706847  0.066714
# Médio                -2.667945  0.010232  0.059053 -0.040740
# Pós graduação        -4.075868  0.547763  1.275110 -1.448663
# Superior completo    -2.769928 -0.058807  0.019381 -0.142723
# Superior incompleto  -2.810939  0.036452  0.221464 -0.183735

# %%
df2.educacao.replace({'Fundamental': 'Fundamental/Médio', 'Médio': 'Fundamental/Médio'}, inplace=True)
df2.educacao.replace({'Pós graduação': 'Superior', 'Superior completo': 'Superior', 'Superior incompleto': 'Superior'}, inplace=True)
df_oot2.educacao.replace({'Fundamental': 'Fundamental/Médio', 'Médio': 'Fundamental/Médio'}, inplace=True)
df_oot2.educacao.replace({'Pós graduação': 'Superior', 'Superior completo': 'Superior', 'Superior incompleto': 'Superior'}, inplace=True)
biv_discreta('educacao', df2)
# Out:
#                    qt_bom  qt_mau       mau           educacao   cont  \
# educacao
# Fundamental/Médio   23102    1702  0.068618  Fundamental/Médio  24804
# Superior            10614     735  0.064763           Superior  11349
#
#                          ep   mau_sup   mau_inf     logit  logit_sup  \
# educacao
# Fundamental/Médio  0.001605  0.071764  0.065472 -2.608115   -2.55990
# Superior           0.002310  0.069292  0.060235 -2.670059   -2.59762
#
#                    logit_inf       woe   woe_sup   woe_inf
# educacao
# Fundamental/Médio  -2.658423  0.019090  0.067305 -0.031219
# Superior           -2.747375 -0.042854  0.029585 -0.120171

# %%
biv_discreta(discretas[5], df);
# Out:
#               qt_bom  qt_mau       mau estado_civil   cont        ep  \
# estado_civil
# Casado         23760    1677  0.065928       Casado  25437  0.001556
# Separado        1848     142  0.071357     Separado   1990  0.005771
# Solteiro        4109     324  0.073088     Solteiro   4433  0.003909
# União           2579     204  0.073302        União   2783  0.004941
# Viúvo           1420      90  0.059603        Viúvo   1510  0.006093
#
#                mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# estado_civil
# Casado        0.068977  0.062878 -2.650997  -2.602506  -2.701619 -0.023792
# Separado      0.082674  0.060040 -2.566032  -2.406562  -2.750829  0.061173
# Solteiro      0.080752  0.065424 -2.540191  -2.432169  -2.659202  0.087013
# União         0.082990  0.063615 -2.537037  -2.402403  -2.689181  0.090168
# Viúvo         0.071553  0.047652 -2.758602  -2.563068  -2.995009 -0.131398
#
#                woe_sup   woe_inf
# estado_civil
# Casado        0.024699 -0.074415
# Separado      0.220643 -0.123624
# Solteiro      0.195035 -0.031997
# União         0.224801 -0.061976
# Viúvo         0.064136 -0.367804

# %%
biv_discreta(discretas[6], df);
# Out:
#                  qt_bom  qt_mau       mau tipo_residencia   cont        ep  \
# tipo_residencia
# Aluguel             463      30  0.060852         Aluguel    493  0.010767
# Casa              30323    2148  0.066151            Casa  32471  0.001379
# Com os pais        1514     145  0.087402     Com os pais   1659  0.006934
# Comunitário         142      13  0.083871     Comunitário    155  0.022265
# Estúdio             236      13  0.052209         Estúdio    249  0.014097
# Governamental      1038      88  0.078153   Governamental   1126  0.007999
#
#                   mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# tipo_residencia
# Aluguel          0.082006  0.039698 -2.736530  -2.415396  -3.185957 -0.109325
# Casa             0.068855  0.063448 -2.647369  -2.604415  -2.691987 -0.020165
# Com os pais      0.101002  0.073802 -2.345777  -2.186139  -2.529703  0.281428
# Comunitário      0.127855  0.039887 -2.390878  -1.920061  -3.180996  0.236327
# Estúdio          0.079974  0.024444 -2.898882  -2.442699  -3.686639 -0.271678
# Governamental    0.093847  0.062458 -2.467714  -2.267539  -2.708763  0.159490
#
#                   woe_sup   woe_inf
# tipo_residencia
# Aluguel          0.211809 -0.558752
# Casa             0.022790 -0.064782
# Com os pais      0.441066  0.097502
# Comunitário      0.707144 -0.553791
# Estúdio          0.184505 -1.059435
# Governamental    0.359666 -0.081559

# %%
biv_continua(continuas[0], 5, df);
# Out:
#               qt_bom  qt_mau       mau      idade  cont        ep   mau_sup  \
# idade
# (21.0, 32.0]    7072     547  0.071794  28.807586  7619  0.002957  0.077592
# (32.0, 39.0]    7125     518  0.067774  36.019495  7643  0.002875  0.073411
# (39.0, 46.0]    6448     462  0.066860  42.825904  6910  0.003005  0.072750
# (46.0, 55.0]    6534     461  0.065904  50.851036  6995  0.002967  0.071720
# (55.0, 68.0]    6537     449  0.064271  60.516318  6986  0.002934  0.070023
#
#                mau_inf     logit  logit_sup  logit_inf       woe   woe_sup  \
# idade
# (21.0, 32.0]  0.065997 -2.559450  -2.475529  -2.649874  0.067755  0.151676
# (32.0, 39.0]  0.062138 -2.621390  -2.535443  -2.714239  0.005815  0.091762
# (39.0, 46.0]  0.060969 -2.635960  -2.545195  -2.734478 -0.008756  0.082010
# (46.0, 55.0]  0.060089 -2.651377  -2.560569  -2.749962 -0.024172  0.066636
# (55.0, 68.0]  0.058520 -2.678211  -2.586335  -2.778089 -0.051006  0.040869
#
#                woe_inf
# idade
# (21.0, 32.0] -0.022669
# (32.0, 39.0] -0.087035
# (39.0, 46.0] -0.107273
# (46.0, 55.0] -0.122757
# (55.0, 68.0] -0.150884

# %%
biv_continua(continuas[1], 12, df);
# Out:
#                        qt_bom  qt_mau       mau  qt_pessoas_residencia   cont  \
# qt_pessoas_residencia
# (0.0, 2.0]              24090    1711  0.066315               1.745552  25801
# (2.0, 3.0]               6046     469  0.071988               3.000000   6515
# (3.0, 4.0]               3140     213  0.063525               4.000000   3353
# (4.0, 15.0]               440      44  0.090909               5.256198    484
#
#                              ep   mau_sup   mau_inf     logit  logit_sup  \
# qt_pessoas_residencia
# (0.0, 2.0]             0.001549  0.069352  0.063279 -2.644719  -2.596692
# (2.0, 3.0]             0.003202  0.078265  0.065710 -2.556549  -2.466156
# (3.0, 4.0]             0.004212  0.071784  0.055267 -2.690686  -2.559605
# (4.0, 15.0]            0.013067  0.116585  0.065233 -2.302585  -2.025176
#
#                        logit_inf       woe   woe_sup   woe_inf
# qt_pessoas_residencia
# (0.0, 2.0]             -2.694834 -0.017514  0.030513 -0.067629
# (2.0, 3.0]             -2.654530  0.070655  0.161049 -0.027325
# (3.0, 4.0]             -2.838735 -0.063481  0.067600 -0.211530
# (4.0, 15.0]            -2.662325  0.324620  0.602028 -0.035121

# %%
biv_continua(continuas[2], 10, df);
# Out:
#              qt_bom  qt_mau       mau  qtd_filhos   cont        ep   mau_sup  \
# qtd_filhos
# (-1.0, 1.0]   29983    2165  0.067345    0.233949  32148  0.001398  0.070084
# (1.0, 2.0]     3277     227  0.064783    2.000000   3504  0.004158  0.072936
# (2.0, 14.0]     456      45  0.089820    3.263473    501  0.012774  0.114918
#
#               mau_inf     logit  logit_sup  logit_inf       woe   woe_sup  \
# qtd_filhos
# (-1.0, 1.0]  0.064605 -2.628210  -2.585393  -2.672675 -0.001005  0.041812
# (1.0, 2.0]   0.056630 -2.669734  -2.542443  -2.812913 -0.042529  0.084762
# (2.0, 14.0]  0.064723 -2.315830  -2.041462  -2.670731  0.311374  0.585743
#
#               woe_inf
# qtd_filhos
# (-1.0, 1.0] -0.045471
# (1.0, 2.0]  -0.185708
# (2.0, 14.0] -0.043526

# %%
biv_continua(continuas[3], 5, df);
# Out:
#                qt_bom  qt_mau       mau  tempo_emprego  cont        ep  \
# tempo_emprego
# (-1.0, 2.0]      5307     614  0.103699       1.119716  5921  0.003962
# (2.0, 4.0]       5429     473  0.080142       3.209461  5902  0.003534
# (4.0, 7.0]       5536     393  0.066284       5.339092  5929  0.003231
# (7.0, 10.0]      5581     335  0.056626       7.960955  5916  0.003005
# (10.0, 34.0]     5699     188  0.031935      13.718547  5887  0.002292
#
#                 mau_sup   mau_inf     logit  logit_sup  logit_inf       woe  \
# tempo_emprego
# (-1.0, 2.0]    0.111466  0.095932 -2.156787  -2.075856  -2.243268  0.470418
# (2.0, 4.0]     0.087071  0.073214 -2.440415  -2.349939  -2.538336  0.186790
# (4.0, 7.0]     0.072618  0.059951 -2.645218  -2.547151  -2.752411 -0.018013
# (7.0, 10.0]    0.062517  0.050735 -2.812993  -2.707762  -2.929065 -0.185788
# (10.0, 34.0]   0.036427  0.027442 -3.411604  -3.275334  -3.567840 -0.784399
#
#                 woe_sup   woe_inf
# tempo_emprego
# (-1.0, 2.0]    0.551348  0.383936
# (2.0, 4.0]     0.277266  0.088869
# (4.0, 7.0]     0.080053 -0.125206
# (7.0, 10.0]   -0.080557 -0.301861
# (10.0, 34.0]  -0.648130 -0.940635

# %%
biv_continua(continuas[4], 5, df);
# Out:
#                     qt_bom  qt_mau       mau         renda  cont        ep  \
# renda
# (167.0, 3601.0]       5990    1241  0.171622   2264.910447  7231  0.004434
# (3601.0, 6662.0]      6699     531  0.073444   5051.391174  7230  0.003068
# (6662.0, 11119.0]     6909     322  0.044530   8693.297060  7231  0.002426
# (11119.0, 19415.0]    7011     219  0.030290  14763.156567  7230  0.002016
# (19415.0, 49986.0]    7107     124  0.017148  30123.616707  7231  0.001527
#
#                      mau_sup   mau_inf     logit  logit_sup  logit_inf  \
# renda
# (167.0, 3601.0]     0.180314  0.162930 -1.574174  -1.514220  -1.636586
# (3601.0, 6662.0]    0.079458  0.067430 -2.534952  -2.449734  -2.626855
# (6662.0, 11119.0]   0.049286  0.039775 -3.066029  -2.959582  -3.183919
# (11119.0, 19415.0]  0.034242  0.026339 -3.466164  -3.339472  -3.610001
# (19415.0, 49986.0]  0.020141  0.014156 -4.048554  -3.884642  -4.243389
#
#                          woe   woe_sup   woe_inf
# renda
# (167.0, 3601.0]     1.053031  1.112985  0.990619
# (3601.0, 6662.0]    0.092253  0.177471  0.000350
# (6662.0, 11119.0]  -0.438824 -0.332377 -0.556714
# (11119.0, 19415.0] -0.838959 -0.712267 -0.982796
# (19415.0, 49986.0] -1.421349 -1.257437 -1.616184

# %% [markdown]
# ## Desenvolvimento do modelo
#
# Desenvolva um modelo de *credit scoring* através de uma regressão logística.
#
# - Trate valores missings e outliers
# - Trate 'zeros estruturais'
# - Faça agrupamentos de categorias conforme vimos em aula
# - Proponha uma equação preditiva para 'mau'
# - Caso hajam categorias não significantes, justifique

# %%
df2['tempo_emprego'] = df2['tempo_emprego'].fillna(df2['tempo_emprego'].mean())

# %%
metadados.sort_values(by='IV', ascending=False)
# Out:
#                          dtype  nmissing  valores_unicos       papel        IV
# tipo_renda              object       0.0             5.0  covariavel       inf
# renda                  float64       0.0         33351.0  covariavel  0.862857
# tempo_emprego          float64    6702.0          2929.0  covariavel  0.317127
# idade                    int64       0.0            47.0  covariavel  0.009294
# posse_de_imovel         object       0.0             2.0  covariavel  0.007228
# tipo_residencia         object       0.0             6.0  covariavel  0.007085
# educacao                object       0.0             5.0  covariavel  0.005935
# estado_civil            object       0.0             5.0  covariavel  0.002943
# sexo                    object       0.0             2.0  covariavel  0.002367
# qt_pessoas_residencia  float64       0.0             9.0  covariavel  0.002194
# posse_de_veiculo        object       0.0             2.0  covariavel  0.001074
# qtd_filhos               int64       0.0             8.0  covariavel  0.000095
# mau                      int64       0.0             2.0    resposta       NaN
# bom                        NaN       NaN             NaN    resposta       NaN

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
df2['tempo_emprego_norm'] = sc_X.fit_transform(df2[['tempo_emprego']])
df2['renda_norm'] = sc_X.fit_transform(df2[['renda']])
df_oot2['tempo_emprego_norm'] = sc_X.fit_transform(df_oot2[['tempo_emprego']])
df_oot2['renda_norm'] = sc_X.fit_transform(df_oot2[['renda']])

formula = 'mau ~ sexo + tipo_renda + tempo_emprego_norm + renda_norm'

rl = smf.glm(formula, data=df2, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:                36153
# Model:                            GLM   Df Residuals:                    36146
# Model Family:                Binomial   Df Model:                            6
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -8245.6
# Date:                Wed, 03 Jan 2024   Deviance:                       16491.
# Time:                        10:40:47   Pearson chi2:                 5.28e+04
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.03692
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -3.0295      0.044    -68.824      0.000      -3.116      -2.943
# sexo[T.M]                         -0.0671      0.047     -1.418      0.156      -0.160       0.026
# tipo_renda[T.Empresário]          -0.0472      0.054     -0.874      0.382      -0.153       0.059
# tipo_renda[T.Pensionista]         -0.0745      0.060     -1.241      0.215      -0.192       0.043
# tipo_renda[T.Servidor público]     0.0106      0.088      0.121      0.904      -0.162       0.184
# tempo_emprego_norm                -0.0518      0.030     -1.755      0.079      -0.110       0.006
# renda_norm                        -1.2410      0.048    -25.843      0.000      -1.335      -1.147
# ==================================================================================================
# """

# %% [markdown]
# ## Avaliação do modelo
#
# Avalie o poder discriminante do modelo pelo menos avaliando acurácia, KS e Gini.
#
# Avalie estas métricas nas bases de desenvolvimento e *out of time*.

# %%
from sklearn import metrics
from scipy.stats import ks_2samp

y_pred = rl.predict(df2[['sexo', 'tipo_renda', 'tempo_emprego_norm', 'renda_norm']])
y_test = df2.mau

previsao = pd.DataFrame()
previsao['teste'] = y_test
previsao['predito'] = y_pred

previsao = previsao[previsao.predito.notna()]
previsao.isna().sum()

acc = metrics.accuracy_score(y_test, y_pred>0.5)
print('Acurácia: {0:.2f}%'.format(acc*100))

#AUC
fpr, tpr, thresholds = metrics.roc_curve(previsao['teste'], previsao['predito'])
auc_ = metrics.auc(fpr, tpr)
# #Gini
gini = 2*auc_ -1
# #KS
ks = ks_2samp(previsao.loc[y_test == 1, 'predito'], previsao.loc[y_test != 1, 'predito']).statistic

print('KS: {0:.2f}% \nAUC: {1:.2f}% \nGINI: {2:.2f}%'
      .format(ks*100, auc_*100, gini*100))
# Out:
# Acurácia: 93.26%
# KS: 36.07%
# AUC: 73.61%
# GINI: 47.23%

# %%
from sklearn import metrics
from scipy.stats import ks_2samp

y_pred = rl.predict(df_oot2[['sexo', 'tipo_renda', 'tempo_emprego_norm', 'renda_norm']])
y_test = df_oot2.mau

previsao = pd.DataFrame()
previsao['teste'] = y_test
previsao['predito'] = y_pred

previsao = previsao[previsao.predito.notna()]
previsao.isna().sum()

acc = metrics.accuracy_score(y_test, y_pred>0.5)
print('Acurácia: {0:.2f}%'.format(acc*100))

#AUC
fpr, tpr, thresholds = metrics.roc_curve(previsao['teste'], previsao['predito'])
auc_ = metrics.auc(fpr, tpr)
# #Gini
gini = 2*auc_ -1
# #KS
ks = ks_2samp(previsao.loc[y_test == 1, 'predito'], previsao.loc[y_test != 1, 'predito']).statistic

print('KS: {0:.2f}% \nAUC: {1:.2f}% \nGINI: {2:.2f}%'
      .format(ks*100, auc_*100, gini*100))
# Out:
# Acurácia: 85.53%
# KS: 37.62%
# AUC: 74.03%
# GINI: 48.06%

# %% [markdown]
# ## Criar um pipeline utilizando o sklearn pipeline

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.ensemble import IsolationForest
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.covariance import EllipticEnvelope

# %% [markdown]
# ## Pré processamento

# %% [markdown]
# ### Substituição de nulos (nans)
#
# Existe nulos na base? é dado numérico ou categórico? qual o valor de substituição? média? valor mais frequente? etc

# %%
imputer = SimpleImputer(strategy='mean')

# %% [markdown]
# ### Remoção de outliers
#
# Como identificar outlier? Substituir o outlier por algum valor? Remover a linha?

# %%
class EllipticEnvelopeTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, contamination=0.1):
        self.contamination = contamination
        self.envelope = EllipticEnvelope(contamination=self.contamination, support_fraction=0.9)

    def fit(self, X, y=None):
        self.envelope.fit(X)
        return self

    def transform(self, X, y=None):
        return self.envelope.predict(X).reshape(-1, 1)

# %%
outliers_removal = EllipticEnvelopeTransformer(contamination=0.1)

# %% [markdown]
# ### Seleção de variáveis
#
# Qual tipo de técnica? Boruta? Feature importance?

# %%
feature_selector = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=42))

# %% [markdown]
# ### Redução de dimensionalidade (PCA)
#
# Aplicar PCA para reduzir a dimensionalidade para 5

# %%
pca_pipe = PCA(n_components=5)

# %% [markdown]
# ### Criação de dummies
#
# Aplicar o get_dummies() ou onehotencoder() para transformar colunas catégoricas do dataframe em colunas de 0 e 1.
# - sexo
# - posse_de_veiculo
# - posse_de_imovel
# - tipo_renda
# - educacao
# - estado_civil
# - tipo_residencia

# %%
dummies = OneHotEncoder(handle_unknown='ignore')

# %% [markdown]
# ### Pipeline
#
# Crie um pipeline contendo essas funções.
#
# preprocessamento()
# - substituicao de nulos
# - remoção outliers
# - PCA
# - Criação de dummy de pelo menos 1 variável (posse_de_veiculo)

# %%
numeric_features = continuas
categorical_features = discretas[:-1]

numeric_transformer = Pipeline(steps=[
    ('imputer', imputer),
    ('outliere_removal', outliers_removal),   
])

categorical_transformer = Pipeline(steps=[
    ('dummy', dummies),
    ('feature_selector', feature_selector),
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

pipe = Pipeline(steps=[('preprocessor', preprocessor),
                           ('pca', pca_pipe),
                           ('log_reg', LogisticRegression(max_iter=200))
                          ])

pipe.fit(df2[variaveis].iloc[:,:-1], df2['mau'])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('outliere_removal',
#                                                                    EllipticEnvelopeTransformer())]),
#                                                   ['idade',
#                                                    'qt_pessoas_residencia',
#                                                    'qtd_filhos',
#                                                    'tempo_emprego', 'renda']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('dummy',
#                                                                    OneHotEncoder(handle_unknown='ignore')),
#                                                                   ('feature_selector',
#                                                                    SelectFromModel(estimator=RandomForestClassifier(random_state=42)))]),
#                                                   ['sexo', 'posse_de_veiculo',
#                                                    'posse_de_imovel',
#                                                    'tipo_renda', 'educacao',
#                                                    'estado_civil',
#                                                    'tipo_residencia'])])),
#                 ('pca', PCA(n_components=5)),
#                 ('log_reg', LogisticRegression(max_iter=200))])

# %% [markdown]
# ### Treinar um modelo de regressão logistica com o resultado

# %%
from sklearn import metrics
from scipy.stats import ks_2samp

y_pred = pipe.predict(df_oot2[variaveis].iloc[:,:-1])
y_test = df_oot2.mau

previsao = pd.DataFrame()
previsao['teste'] = y_test
previsao['predito'] = y_pred

previsao = previsao[previsao.predito.notna()]
previsao.isna().sum()

acc = metrics.accuracy_score(y_test, y_pred>0.5)
print('Acurácia: {0:.2f}%'.format(acc*100))

#AUC
fpr, tpr, thresholds = metrics.roc_curve(previsao['teste'], previsao['predito'])
auc_ = metrics.auc(fpr, tpr)
# #Gini
gini = 2*auc_ -1
# #KS
ks = ks_2samp(previsao.loc[y_test == 1, 'predito'], previsao.loc[y_test != 1, 'predito']).statistic

print('KS: {0:.2f}% \nAUC: {1:.2f}% \nGINI: {2:.2f}%'
      .format(ks*100, auc_*100, gini*100))
# Out:
# Acurácia: 85.53%
# KS: 0.00%
# AUC: 50.00%
# GINI: 0.00%

# %% [markdown]
# ### Salvar o pickle file do modelo treinado

# %%
import pickle

nome_arquivo = '../models/sklearn_model.pkl'
pickle.dump(pipe, open(nome_arquivo, 'wb'))

# %% [markdown]
# # Pycaret na base de dados
#
# Utilize o pycaret para pre processar os dados e rodar o modelo **lightgbm**. Faça todos os passos a passos da aula e gere os gráficos finais. E o pipeline de toda a transformação.

# %%
from pycaret.classification import *
setup = setup(
    data = df,
    target = 'mau',
    numeric_imputation='mean',
    normalize=True,           
    remove_outliers=True,     
    pca=True,                 
    pca_components=5,
    normalize_method='zscore', 
    transformation=True,
    transformation_method = 'quantile',
    fix_imbalance=True
)
models()
# Out:
# <style type="text/css">
# #T_cebc5_row12_col1, #T_cebc5_row18_col1, #T_cebc5_row20_col1, #T_cebc5_row22_col1, #T_cebc5_row24_col1, #T_cebc5_row26_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cebc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cebc5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_cebc5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cebc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cebc5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_cebc5_row0_col1" class="data row0 col1" >1046</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cebc5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cebc5_row1_col1" class="data row1 col1" >mau</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cebc5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_cebc5_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cebc5_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_cebc5_row3_col1" class="data row3 col1" >(36153, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cebc5_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_cebc5_row4_col1" class="data row4 col1" >(56072, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cebc5_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_cebc5_row5_col1" class="data row5 col1" >(45226, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cebc5_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_cebc5_row6_col1" class="data row6 col1" >(10846, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cebc5_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_cebc5_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cebc5_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_cebc5_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cebc5_row9_col0" class="data row9 col0" >Date features</td>
#       <td id="T_cebc5_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cebc5_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_cebc5_row10_col1" class="data row10 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cebc5_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_cebc5_row11_col1" class="data row11 col1" >18.3%</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cebc5_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_cebc5_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cebc5_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_cebc5_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cebc5_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_cebc5_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cebc5_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_cebc5_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cebc5_row16_col0" class="data row16 col0" >Maximum one-hot encoding</td>
#       <td id="T_cebc5_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cebc5_row17_col0" class="data row17 col0" >Encoding method</td>
#       <td id="T_cebc5_row17_col1" class="data row17 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cebc5_row18_col0" class="data row18 col0" >Remove outliers</td>
#       <td id="T_cebc5_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cebc5_row19_col0" class="data row19 col0" >Outliers threshold</td>
#       <td id="T_cebc5_row19_col1" class="data row19 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_cebc5_row20_col0" class="data row20 col0" >Fix imbalance</td>
#       <td id="T_cebc5_row20_col1" class="data row20 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_cebc5_row21_col0" class="data row21 col0" >Fix imbalance method</td>
#       <td id="T_cebc5_row21_col1" class="data row21 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_cebc5_row22_col0" class="data row22 col0" >Transformation</td>
#       <td id="T_cebc5_row22_col1" class="data row22 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_cebc5_row23_col0" class="data row23 col0" >Transformation method</td>
#       <td id="T_cebc5_row23_col1" class="data row23 col1" >quantile</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_cebc5_row24_col0" class="data row24 col0" >Normalize</td>
#       <td id="T_cebc5_row24_col1" class="data row24 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_cebc5_row25_col0" class="data row25 col0" >Normalize method</td>
#       <td id="T_cebc5_row25_col1" class="data row25 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_cebc5_row26_col0" class="data row26 col0" >PCA</td>
#       <td id="T_cebc5_row26_col1" class="data row26 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_cebc5_row27_col0" class="data row27 col0" >PCA method</td>
#       <td id="T_cebc5_row27_col1" class="data row27 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_cebc5_row28_col0" class="data row28 col0" >PCA components</td>
#       <td id="T_cebc5_row28_col1" class="data row28 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_cebc5_row29_col0" class="data row29 col0" >Fold Generator</td>
#       <td id="T_cebc5_row29_col1" class="data row29 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cebc5_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_cebc5_row30_col0" class="data row30 col0" >Fold
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_076c4_row10_col0, #T_076c4_row10_col1, #T_076c4_row10_col2, #T_076c4_row10_col3, #T_076c4_row10_col4, #T_076c4_row10_col5, #T_076c4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_076c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_076c4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_076c4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_076c4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_076c4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_076c4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_076c4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_076c4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_076c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_076c4_row0_col0" class="data row0 col0" >0.8866</td>
#       <td id="T_076c4_row0_col1" class="data row0 col1" >0.8253</td>
#       <td id="T_076c4_row0_col2" class="data row0 col2" >0.5471</td>
#       <td id="T_076c4_row0_col3" class="data row0 col3" >0.3069</td>
#       <td id="T_076c4_row0_col4" class="data row0 col4" >0.3932</td>
#       <td id="T_076c4_row0_col5" class="data row0 col5" >0.3361</td>
#       <td id="T_076c4_row0_col6" class="data row0 col6" >0.3532</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_076c4_row1_col0" class="data row1 col0" >0.8736</td>
#       <td id="T_076c4_row1_col1" class="data row1 col1" >0.8255</td>
#       <td id="T_076c4_row1_col2" class="data row1 col2" >0.5497</td>
#       <td id="T_076c4_row1_col3" class="data row1 col3" >0.2789</td>
#       <td id="T_076c4_row1_col4" class="data row1 col4" >0.3701</td>
#       <td id="T_076c4_row1_col5" class="data row1 col5" >0.3081</td>
#       <td id="T_076c4_row1_col6" class="data row1 col6" >0.3300</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_076c4_row2_col0" class="data row2 col0" >0.8787</td>
#       <td id="T_076c4_row2_col1" class="data row2 col1" >0.8792</td>
#       <td id="T_076c4_row2_col2" class="data row2 col2" >0.6725</td>
#       <td id="T_076c4_row2_col3" class="data row2 col3" >0.3142</td>
#       <td id="T_076c4_row2_col4" class="data row2 col4" >0.4283</td>
#       <td id="T_076c4_row2_col5" class="data row2 col5" >0.3703</td>
#       <td id="T_076c4_row2_col6" class="data row2 col6" >0.4040</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_076c4_row3_col0" class="data row3 col0" >0.8834</td>
#       <td id="T_076c4_row3_col1" class="data row3 col1" >0.8660</td>
#       <td id="T_076c4_row3_col2" class="data row3 col2" >0.6608</td>
#       <td id="T_076c4_row3_col3" class="data row3 col3" >0.3229</td>
#       <td id="T_076c4_row3_col4" class="data row3 col4" >0.4338</td>
#       <td id="T_076c4_row3_col5" class="data row3 col5" >0.3773</td>
#       <td id="T_076c4_row3_col6" class="data row3 col6" >0.4075</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_076c4_row4_col0" class="data row4 col0" >0.8913</td>
#       <td id="T_076c4_row4_col1" class="data row4 col1" >0.8750</td>
#       <td id="T_076c4_row4_col2" class="data row4 col2" >0.6901</td>
#       <td id="T_076c4_row4_col3" class="data row4 col3" >0.3471</td>
#       <td id="T_076c4_row4_col4" class="data row4 col4" >0.4618</td>
#       <td id="T_076c4_row4_col5" class="data row4 col5" >0.4087</td>
#       <td id="T_076c4_row4_col6" class="data row4 col6" >0.4387</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_076c4_row5_col0" class="data row5 col0" >0.8637</td>
#       <td id="T_076c4_row5_col1" class="data row5 col1" >0.8465</td>
#       <td id="T_076c4_row5_col2" class="data row5 col2" >0.6082</td>
#       <td id="T_076c4_row5_col3" class="data row5 col3" >0.2723</td>
#       <td id="T_076c4_row5_col4" class="data row5 col4" >0.3761</td>
#       <td id="T_076c4_row5_col5" class="data row5 col5" >0.3119</td>
#       <td id="T_076c4_row5_col6" class="data row5 col6" >0.3438</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_076c4_row6_col0" class="data row6 col0" >0.8771</td>
#       <td id="T_076c4_row6_col1" class="data row6 col1" >0.8456</td>
#       <td id="T_076c4_row6_col2" class="data row6 col2" >0.5556</td>
#       <td id="T_076c4_row6_col3" class="data row6 col3" >0.2879</td>
#       <td id="T_076c4_row6_col4" class="data row6 col4" >0.3792</td>
#       <td id="T_076c4_row6_col5" class="data row6 col5" >0.3186</td>
#       <td id="T_076c4_row6_col6" class="data row6 col6" >0.3399</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_076c4_row7_col0" class="data row7 col0" >0.8794</td>
#       <td id="T_076c4_row7_col1" class="data row7 col1" >0.8793</td>
#       <td id="T_076c4_row7_col2" class="data row7 col2" >0.6471</td>
#       <td id="T_076c4_row7_col3" class="data row7 col3" >0.3099</td>
#       <td id="T_076c4_row7_col4" class="data row7 col4" >0.4190</td>
#       <td id="T_076c4_row7_col5" class="data row7 col5" >0.3610</td>
#       <td id="T_076c4_row7_col6" class="data row7 col6" >0.3916</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_076c4_row8_col0" class="data row8 col0" >0.8783</td>
#       <td id="T_076c4_row8_col1" class="data row8 col1" >0.8841</td>
#       <td id="T_076c4_row8_col2" class="data row8 col2" >0.6647</td>
#       <td id="T_076c4_row8_col3" class="data row8 col3" >0.3104</td>
#       <td id="T_076c4_row8_col4" class="data row8 col4" >0.4232</td>
#       <td id="T_076c4_row8_col5" class="data row8 col5" >0.3651</td>
#       <td id="T_076c4_row8_col6" class="data row8 col6" >0.3983</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_076c4_row9_col0" class="data row9 col0" >0.8652</td>
#       <td id="T_076c4_row9_col1" class="data row9 col1" >0.8580</td>
#       <td id="T_076c4_row9_col2" class="data row9 col2" >0.6176</td>
#       <td id="T_076c4_row9_col3" class="data row9 col3" >0.2756</td>
#       <td id="T_076c4_row9_col4" class="data row9 col4" >0.3811</td>
#       <td id="T_076c4_row9_col5" class="data row9 col5" >0.3177</td>
#       <td id="T_076c4_row9_col6" class="data row9 col6" >0.3505</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_076c4_row10_col0" class="data row10 col0" >0.8777</td>
#       <td id="T_076c4_row10_col1" class="data row10 col1" >0.8584</td>
#       <td id="T_076c4_row10_col2" class="data row10 col2" >0.6213</td>
#       <td id="T_076c4_row10_col3" class="data row10 col3" >0.3026</td>
#       <td id="T_076c4_row10_col4" class="data row10 col4" >0.4066</td>
#       <td id="T_076c4_row10_col5" class="data row10 col5" >0.3475</td>
#       <td id="T_076c4_row10_col6" class="data row10 col6" >0.3758</td>
#     </tr>
#     <tr>
#       <th id="T_076c4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_076c4_row11_col0" class="data row11 col0" >0.0082</td>
#       <td id="T_076c4_row11_col1" class="data row11 col1" >0.0208</td>
#       <td id="T_076c4_row11_col2" class="data row11 col2" >0.0516</td>
#       <td id="T_076c4_row11_col3" class="data row11 col3" >0.0225</td>
#       <td id="T_076c4_row11_col4

# %%
tuned_lightgbm = tune_model(lightgbm, optimize='AUC')
# Out:
# <style type="text/css">
# #T_e470e_row10_col0, #T_e470e_row10_col1, #T_e470e_row10_col2, #T_e470e_row10_col3, #T_e470e_row10_col4, #T_e470e_row10_col5, #T_e470e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e470e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e470e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e470e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e470e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e470e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e470e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e470e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e470e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e470e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e470e_row0_col0" class="data row0 col0" >0.9147</td>
#       <td id="T_e470e_row0_col1" class="data row0 col1" >0.8456</td>
#       <td id="T_e470e_row0_col2" class="data row0 col2" >0.4882</td>
#       <td id="T_e470e_row0_col3" class="data row0 col3" >0.3915</td>
#       <td id="T_e470e_row0_col4" class="data row0 col4" >0.4346</td>
#       <td id="T_e470e_row0_col5" class="data row0 col5" >0.3890</td>
#       <td id="T_e470e_row0_col6" class="data row0 col6" >0.3918</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e470e_row1_col0" class="data row1 col0" >0.9068</td>
#       <td id="T_e470e_row1_col1" class="data row1 col1" >0.8529</td>
#       <td id="T_e470e_row1_col2" class="data row1 col2" >0.4912</td>
#       <td id="T_e470e_row1_col3" class="data row1 col3" >0.3605</td>
#       <td id="T_e470e_row1_col4" class="data row1 col4" >0.4158</td>
#       <td id="T_e470e_row1_col5" class="data row1 col5" >0.3665</td>
#       <td id="T_e470e_row1_col6" class="data row1 col6" >0.3717</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e470e_row2_col0" class="data row2 col0" >0.8953</td>
#       <td id="T_e470e_row2_col1" class="data row2 col1" >0.8774</td>
#       <td id="T_e470e_row2_col2" class="data row2 col2" >0.5789</td>
#       <td id="T_e470e_row2_col3" class="data row2 col3" >0.3390</td>
#       <td id="T_e470e_row2_col4" class="data row2 col4" >0.4276</td>
#       <td id="T_e470e_row2_col5" class="data row2 col5" >0.3743</td>
#       <td id="T_e470e_row2_col6" class="data row2 col6" >0.3906</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e470e_row3_col0" class="data row3 col0" >0.9127</td>
#       <td id="T_e470e_row3_col1" class="data row3 col1" >0.8862</td>
#       <td id="T_e470e_row3_col2" class="data row3 col2" >0.6433</td>
#       <td id="T_e470e_row3_col3" class="data row3 col3" >0.4074</td>
#       <td id="T_e470e_row3_col4" class="data row3 col4" >0.4989</td>
#       <td id="T_e470e_row3_col5" class="data row3 col5" >0.4537</td>
#       <td id="T_e470e_row3_col6" class="data row3 col6" >0.4679</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e470e_row4_col0" class="data row4 col0" >0.9154</td>
#       <td id="T_e470e_row4_col1" class="data row4 col1" >0.8982</td>
#       <td id="T_e470e_row4_col2" class="data row4 col2" >0.6374</td>
#       <td id="T_e470e_row4_col3" class="data row4 col3" >0.4176</td>
#       <td id="T_e470e_row4_col4" class="data row4 col4" >0.5046</td>
#       <td id="T_e470e_row4_col5" class="data row4 col5" >0.4606</td>
#       <td id="T_e470e_row4_col6" class="data row4 col6" >0.4729</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e470e_row5_col0" class="data row5 col0" >0.8973</td>
#       <td id="T_e470e_row5_col1" class="data row5 col1" >0.8633</td>
#       <td id="T_e470e_row5_col2" class="data row5 col2" >0.6023</td>
#       <td id="T_e470e_row5_col3" class="data row5 col3" >0.3492</td>
#       <td id="T_e470e_row5_col4" class="data row5 col4" >0.4421</td>
#       <td id="T_e470e_row5_col5" class="data row5 col5" >0.3899</td>
#       <td id="T_e470e_row5_col6" class="data row5 col6" >0.4075</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e470e_row6_col0" class="data row6 col0" >0.9060</td>
#       <td id="T_e470e_row6_col1" class="data row6 col1" >0.8675</td>
#       <td id="T_e470e_row6_col2" class="data row6 col2" >0.5614</td>
#       <td id="T_e470e_row6_col3" class="data row6 col3" >0.3707</td>
#       <td id="T_e470e_row6_col4" class="data row6 col4" >0.4465</td>
#       <td id="T_e470e_row6_col5" class="data row6 col5" >0.3975</td>
#       <td id="T_e470e_row6_col6" class="data row6 col6" >0.4077</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e470e_row7_col0" class="data row7 col0" >0.9071</td>
#       <td id="T_e470e_row7_col1" class="data row7 col1" >0.8846</td>
#       <td id="T_e470e_row7_col2" class="data row7 col2" >0.6353</td>
#       <td id="T_e470e_row7_col3" class="data row7 col3" >0.3843</td>
#       <td id="T_e470e_row7_col4" class="data row7 col4" >0.4789</td>
#       <td id="T_e470e_row7_col5" class="data row7 col5" >0.4313</td>
#       <td id="T_e470e_row7_col6" class="data row7 col6" >0.4478</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e470e_row8_col0" class="data row8 col0" >0.9087</td>
#       <td id="T_e470e_row8_col1" class="data row8 col1" >0.9000</td>
#       <td id="T_e470e_row8_col2" class="data row8 col2" >0.6353</td>
#       <td id="T_e470e_row8_col3" class="data row8 col3" >0.3899</td>
#       <td id="T_e470e_row8_col4" class="data row8 col4" >0.4832</td>
#       <td id="T_e470e_row8_col5" class="data row8 col5" >0.4363</td>
#       <td id="T_e470e_row8_col6" class="data row8 col6" >0.4520</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e470e_row9_col0" class="data row9 col0" >0.8980</td>
#       <td id="T_e470e_row9_col1" class="data row9 col1" >0.8648</td>
#       <td id="T_e470e_row9_col2" class="data row9 col2" >0.5588</td>
#       <td id="T_e470e_row9_col3" class="data row9 col3" >0.3417</td>
#       <td id="T_e470e_row9_col4" class="data row9 col4" >0.4241</td>
#       <td id="T_e470e_row9_col5" class="data row9 col5" >0.3717</td>
#       <td id="T_e470e_row9_col6" class="data row9 col6" >0.3853</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e470e_row10_col0" class="data row10 col0" >0.9062</td>
#       <td id="T_e470e_row10_col1" class="data row10 col1" >0.8740</td>
#       <td id="T_e470e_row10_col2" class="data row10 col2" >0.5832</td>
#       <td id="T_e470e_row10_col3" class="data row10 col3" >0.3752</td>
#       <td id="T_e470e_row10_col4" class="data row10 col4" >0.4556</td>
#       <td id="T_e470e_row10_col5" class="data row10 col5" >0.4071</td>
#       <td id="T_e470e_row10_col6" class="data row10 col6" >0.4195</td>
#     </tr>
#     <tr>
#       <th id="T_e470e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e470e_row11_col0" class="data row11 col0" >0.0069</td>
#       <td id="T_e470e_row11_col1" class="data row11 col1" >0.0174</td>
#       <td id="T_e470e_row11_col2" class="data row11 col2" >0.0556</td>
#       <td id="T_e470e_row11_col3" class="data row11 col3" >0.0260</td>
#       <td id="T_e470e_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
plot_model(tuned_lightgbm, plot = 'auc')

# %%
plot_model(tuned_lightgbm, plot = 'pr')

# %%
plot_model(tuned_lightgbm, plot = 'feature')

# %%
plot_model(tuned_lightgbm, plot = 'confusion_matrix')

# %%
predict_model(tuned_lightgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2cfa0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cfa0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2cfa0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2cfa0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2cfa0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2cfa0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2cfa0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2cfa0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2cfa0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cfa0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cfa0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2cfa0_row0_col1" class="data row0 col1" >0.9105</td>
#       <td id="T_2cfa0_row0_col2" class="data row0 col2" >0.8851</td>
#       <td id="T_2cfa0_row0_col3" class="data row0 col3" >0.6088</td>
#       <td id="T_2cfa0_row0_col4" class="data row0 col4" >0.3938</td>
#       <td id="T_2cfa0_row0_col5" class="data row0 col5" >0.4782</td>
#       <td id="T_2cfa0_row0_col6" class="data row0 col6" >0.4317</td>
#       <td id="T_2cfa0_row0_col7" class="data row0 col7" >0.4440</td>
#     </tr>
#   </tbody>
# </table>
#          data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 383698 2015-08-01   4415    F                S               N           0
# 251195 2015-06-01  13310    M                N               S           2
# 42214  2015-01-01  11668    F                N               N           0
# 191953 2015-04-01  15907    F                N               N           0
# 55507  2015-02-01    288    F                N               N           0
# ...           ...    ...  ...              ...             ...         ...
# 496912 2015-10-01   7558    F                S               S           0
# 418352 2015-09-01   7405    F                S               N           2
# 449294 2015-09-01   8155    M                S               S           0
# 99073  2015-02-01   2000    F                N               S           1
# 515770 2015-11-01  16247    F                N               S           0
#
#          tipo_renda             educacao estado_civil tipo_residencia  idade  \
# 383698   Empresário  Superior incompleto       Casado            Casa     47
# 251195  Assalariado                Médio       Casado            Casa     54
# 42214   Assalariado                Médio       Casado            Casa     38
# 191953   Empresário    Superior completo       Casado            Casa     30
# 55507   Pensionista                Médio       Casado            Casa     58
# ...             ...                  ...          ...             ...    ...
# 496912  Assalariado                Médio     Separado            Casa     44
# 418352  Assalariado                Médio       Casado     Com os pais     36
# 449294  Assalariado                Médio       Casado            Casa     53
# 99073   Assalariado                Médio       Casado            Casa     41
# 515770  Assalariado    Superior completo       Casado            Casa     33
#
#         tempo_emprego  qt_pessoas_residencia         renda  bom  mau  \
# 383698       6.430137                    2.0  15179.480469    1    0
# 251195      16.610958                    4.0  37209.660156    1    0
# 42214        3.326027                    2.0   2494.830078    1    0
# 191953       1.123288                    2.0   5179.490234    0    1
# 55507             NaN                    2.0   6785.930176    1    0
# ...               ...                    ...           ...  ...  ...
# 496912       3.852055                    1.0   8114.149902    1    0
# 418352       6.301370                    4.0  23300.320312    1    0
# 449294       8.893150                    2.0  38150.421875    1    0
# 99073        8.597260                    3.0   3146.909912    0    1
# 515770       4.964384                    2.0   2743.550049    1    0
#
#         prediction_label  prediction_score
# 383698                 0            0.5178
# 251195                 0            0.9705
# 42214                  0            0.8238
# 191953                 0            0.5801
# 55507                  0            0.9931
# ...                  ...               ...
# 496912                 0            0.9847
# 418352                 0            0.9446
# 449294                 0            0.9991
# 99073                  1            0.9833
# 515770                 0            0.9681
#
# [10846 rows x 18 columns]

# %%
final_lightgbm = finalize_model(tuned_lightgbm)
print(final_lightgbm)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('date_feature_extractor',
#                  TransformerWrapper(exclude=None, include=['data_ref'],
#                                     transformer=ExtractDateTimeFeatures(features=['day',
#                                                                                   'month',
#                                                                                   'year']))),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['index', 'qtd_filhos', 'idade',
#                                              'tempo_emprego',
#                                              'qt_pessoas_residencia', 'renda',
#                                              'bom'],
#                                     transform...
#                                 colsample_bytree=1.0, feature_fraction=0.9,
#                                 importance_type='split', learning_rate=0.3,
#                                 max_depth=-1, min_child_samples=100,
#                                 min_child_weight=0.001, min_split_gain=0.9,
#                                 n_estimators=170, n_jobs=-1, num_leaves=200,
#                                 objective=None, random_state=1046,
#                                 reg_alpha=0.005, reg_lambda=1e-06,
#                                 silent='warn', subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
predict_model(final_lightgbm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ae76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ae76_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9ae76_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9ae76_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9ae76_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9ae76_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9ae76_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9ae76_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9ae76_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ae76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ae76_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9ae76_row0_col1" class="data row0 col1" >0.8553</td>
#       <td id="T_9ae76_row0_col2" class="data row0 col2" >0.8124</td>
#       <td id="T_9ae76_row0_col3" class="data row0 col3" >0.5910</td>
#       <td id="T_9ae76_row0_col4" class="data row0 col4" >0.2538</td>
#       <td id="T_9ae76_row0_col5" class="data row0 col5" >0.3551</td>
#       <td id="T_9ae76_row0_col6" class="data row0 col6" >0.2880</td>
#       <td id="T_9ae76_row0_col7" class="data row0 col7" >0.3208</td>
#     </tr>
#   </tbody>
# </table>
#          data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 383698 2015-08-01   4415    F                S               N           0
# 251195 2015-06-01  13310    M                N               S           2
# 42214  2015-01-01  11668    F                N               N           0
# 191953 2015-04-01  15907    F                N               N           0
# 55507  2015-02-01    288    F                N               N           0
# ...           ...    ...  ...              ...             ...         ...
# 496912 2015-10-01   7558    F                S               S           0
# 418352 2015-09-01   7405    F                S               N           2
# 449294 2015-09-01   8155    M                S               S           0
# 99073  2015-02-01   2000    F                N               S           1
# 515770 2015-11-01  16247    F                N               S           0
#
#          tipo_renda             educacao estado_civil tipo_residencia  idade  \
# 383698   Empresário  Superior incompleto       Casado            Casa     47
# 251195  Assalariado                Médio       Casado            Casa     54
# 42214   Assalariado                Médio       Casado            Casa     38
# 191953   Empresário    Superior completo       Casado            Casa     30
# 55507   Pensionista                Médio       Casado            Casa     58
# ...             ...                  ...          ...             ...    ...
# 496912  Assalariado                Médio     Separado            Casa     44
# 418352  Assalariado                Médio       Casado     Com os pais     36
# 449294  Assalariado                Médio       Casado            Casa     53
# 99073   Assalariado                Médio       Casado            Casa     41
# 515770  Assalariado    Superior completo       Casado            Casa     33
#
#         tempo_emprego  qt_pessoas_residencia         renda  bom  mau  \
# 383698       6.430137                    2.0  15179.480469    1    0
# 251195      16.610958                    4.0  37209.660156    1    0
# 42214        3.326027                    2.0   2494.830078    1    0
# 191953       1.123288                    2.0   5179.490234    0    1
# 55507             NaN                    2.0   6785.930176    1    0
# ...               ...                    ...           ...  ...  ...
# 496912       3.852055                    1.0   8114.149902    1    0
# 418352       6.301370                    4.0  23300.320312    1    0
# 449294       8.893150                    2.0  38150.421875    1    0
# 99073        8.597260                    3.0   3146.909912    0    1
# 515770       4.964384                    2.0   2743.550049    1    0
#
#         prediction_label  prediction_score
# 383698                 0            0.6876
# 251195                 0            0.9965
# 42214                  0            0.7820
# 191953                 1            0.8825
# 55507                  0            0.9981
# ...                  ...               ...
# 496912                 0            0.8731
# 418352                 0            0.9953
# 449294                 0            0.9969
# 99073                  1            0.9950
# 515770                 0            0.7936
#
# [10846 rows x 18 columns]

# %%
df_oot['bom'] = 1-df_oot.mau
unseen_predictions = predict_model(lightgbm, data=df_oot2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_024a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_024a0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_024a0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_024a0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_024a0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_024a0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_024a0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_024a0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_024a0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_024a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_024a0_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_024a0_row0_col1" class="data row0 col1" >0.4005</td>
#       <td id="T_024a0_row0_col2" class="data row0 col2" >0.7095</td>
#       <td id="T_024a0_row0_col3" class="data row0 col3" >0.8988</td>
#       <td id="T_024a0_row0_col4" class="data row0 col4" >0.1820</td>
#       <td id="T_024a0_row0_col5" class="data row0 col5" >0.3027</td>
#       <td id="T_024a0_row0_col6" class="data row0 col6" >0.0816</td>
#       <td id="T_024a0_row0_col7" class="data row0 col7" >0.1676</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.utils.generic import check_metric
check_metric(unseen_predictions['mau'], unseen_predictions['prediction_label'], metric = 'Accuracy')
# Out:
# 0.4005

# %% [markdown]
# ### Salvar o arquivo do modelo treinado

# %%
save_model(final_lightgbm,'../models/pycaret_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('date_feature_extractor',
#                   TransformerWrapper(exclude=None, include=['data_ref'],
#                                      transformer=ExtractDateTimeFeatures(features=['day',
#                                                                                    'month',
#                                                                                    'year']))),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['index', 'qtd_filhos', 'idade',
#                                               'tempo_emprego',
#                                               'qt_pessoas_residencia', 'renda',
#                                               'bom'],
#                                      transform...
#                                  colsample_bytree=1.0, feature_fraction=0.9,
#                                  importance_type='split', learning_rate=0.3,
#                                  max_depth=-1, min_child_samples=100,
#                                  min_child_weight=0.001, min_split_gain=0.9,
#                                  n_estimators=170, n_jobs=-1, num_leaves=200,
#                                  objective=None, random_state=1046,
#                                  reg_alpha=0.005, reg_lambda=1e-06,
#                                  silent='warn', subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'Models/pycaret_model.pkl')

# %% [markdown]
# # Projeto Final
#
# 1. Subir no GITHUB todos os jupyter notebooks/códigos que você desenvolveu nesse ultimo módulo
# 1. Gerar um arquivo python (.py) com todas as funções necessárias para rodar no streamlit a escoragem do arquivo de treino
#     - Criar um .py
#     - Criar um carregador de csv no streamlit
#     - Subir um csv no streamlit
#     - Criar um pipeline de pré processamento dos dados
#     - Utilizar o modelo treinado para escorar a base
#         - nome_arquivo = 'model_final.pkl'
# 1. Gravar um vídeo da tela do streamlit em funcionamento (usando o próprio streamlit (temos aula disso) ou qlqr outra forma de gravação).
# 1. Subir no Github o vídeo de funcionamento da ferramenta como README.md.
# 1. Subir no Github os códigos desenvolvidos.
# 1. Enviar links do github para o tutor corrigir.
