# %% [markdown]
# # Previsão de renda

# %% [markdown]
# ### 4 elementos importantes
# - Esse notebook
# - Streamlit com as análises
# - Seu Github com o projeto
# - Vídeo no readme do github mostrando o streamlit

# %% [markdown]
# ## Etapa 1 CRISP - DM: Entendimento do negócio
#
# <span style="color:red">Projeto de criação de um modelo de regressão linear que faça a previsão de renda de uma pessoa baseada nos dados apresentados.</span>

# %% [markdown]
# ## Etapa 2 Crisp-DM: Entendimento dos dados
# <span style="color:red">Abaixo está o dicionário dos dados.</span>
#
#
# ### Dicionário de dados
#
#
# | Variável                | Descrição                                            | Tipo         |
# | ----------------------- |:----------------------------------------------------:| ------------:|
# |data_ref                |  Data de referência de coleta das variáveis           | object       |
# |id_cliente              |  Código de identificação do cliente                   | int64        |
# |sexo                    |  Sexo do cliente                                      | object       |
# |posse_de_veiculo        |  Indica se o cliente possui veículo                   | bool         |
# |posse_de_imovel         |  Indica se o cliente possui imóvel                    | bool         |
# |qtd_filhos              |  Quantidade de filhos do cliente                      | int64        |
# |tipo_renda              |  Tipo de renda do cliente                             | object       |
# |educacao                |  Grau de instrução do cliente                         | object       |
# |estado_civil            |  Estado civil do cliente                              | object       |
# |tipo_residencia         |  Tipo de residência do cliente (própria, alugada etc) | object       |
# |idade                   |  Idade do cliente                                     | int64        |
# |tempo_emprego           |  Tempo no emprego atual                               | float64      |
# |qt_pessoas_residencia   |  Quantidade de pessoas que moram na residência        | float64      |
# |renda                   |  Renda em reais                                       | float64      |

# %% [markdown]
# #### Carregando os pacotes
# É considerado uma boa prática carregar os pacotes que serão utilizados como a primeira coisa do programa.

# %% [markdown]
# <span style="color:red">Para este projeto serão utilizados os seguintes pacotes:</span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport
# %matplotlib inline

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %% [markdown]
# #### Carregando os dados
# O comando pd.read_csv é um comando da biblioteca pandas (pd.) e carrega os dados do arquivo csv indicado para um objeto *dataframe* do pandas.

# %% [markdown]
# <span style="color:red">Os dados são carregados e divididos em base de treino e teste, baseada na data de referência.</span>

# %%
renda = pd.read_csv('./input/previsao_de_renda.csv',)

# %%
renda.head(1)
# Out:
#    Unnamed: 0    data_ref  id_cliente sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01       15056    F             False             True
#
#    qtd_filhos  tipo_renda    educacao estado_civil tipo_residencia  idade  \
# 0           0  Empresário  Secundário     Solteiro            Casa     26
#
#    tempo_emprego  qt_pessoas_residencia    renda
# 0        6.60274                    1.0  8060.34

# %%
renda_treino = renda.query("data_ref < '2016-01-01'")
renda_teste = renda.query("data_ref >= '2016-01-01'")

# %% [markdown]
# #### Entendimento dos dados - Univariada
# Nesta etapa tipicamente avaliamos a distribuição de todas as variáveis.

# %%
prof = ProfileReport(renda_treino, explorative=True, minimal=True)
prof
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-29 13:38:51.953723&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
prof.to_file('./output/renda_analisys.html')
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Entendimento dos dados - Bivariadas

# %% [markdown]
# <span style="color:red">As análises de bivariadas abaixo mostram importantes diferenças de rendas segundo variváveis como tipo de renda, educação e idade. Em todas elas é possível observar uma diferença significativa de renda maior para o sexo masculino do que para o feminino.</span>

# %%
sns.catplot(x='tipo_renda', y='renda'
            , hue = 'sexo'
            , kind='bar'
            , estimator = 'mean'
            , data=renda_treino
            , errorbar=None
            , aspect=2
           )

# %%
sns.catplot(x='educacao', y='renda'
            , hue = 'sexo'
            , kind='bar'
            , estimator = 'mean'
            , data=renda_treino
            , errorbar=None
            , aspect=2
           )

# %%
sns.catplot(x='sexo', y='renda'
            , hue = 'idade'
            , kind='bar'
            , estimator = 'mean'
            , data=renda_treino
            , errorbar=None
            , aspect=2
           )

# %%
sns.catplot(x='posse_de_veiculo', y='renda'
            , hue = 'posse_de_imovel'
            , kind='bar'
            , estimator = 'mean'
            , data=renda_treino
            , errorbar=None
            , aspect=2
           )

# %% [markdown]
# ## Etapa 3 Crisp-DM: Preparação dos dados
# Nessa etapa realizamos tipicamente as seguintes operações com os dados:
#
#  - **seleção**: Já temos os dados selecionados adequadamente?
#  - **limpeza**: Precisaremos identificar e tratar dados faltantes
#  - **construção**: construção de novas variáveis
#  - **integração**: Temos apenas uma fonte de dados, não é necessário integração
#  - **formatação**: Os dados já se encontram em formatos úteis?

# %% [markdown]
# <span style="color:red">Nestes dados foi feita a substituição de dados faltantes pela média, para a variável `tempo_emprego`. Depois foram removidos outliers da variável `renda`. E por fim, foi removida a variável `qt_pessoas_residencia` pois apreseta correlação alta com `qt_filhos`.</span>

# %%
renda_treino.isna().sum()
# Out:
# Unnamed: 0                  0
# data_ref                    0
# id_cliente                  0
# sexo                        0
# posse_de_veiculo            0
# posse_de_imovel             0
# qtd_filhos                  0
# tipo_renda                  0
# educacao                    0
# estado_civil                0
# tipo_residencia             0
# idade                       0
# tempo_emprego            2038
# qt_pessoas_residencia       0
# renda                       0
# dtype: int64

# %%
renda_treino.tempo_emprego = renda_treino.tempo_emprego.fillna(renda_treino.tempo_emprego.mean())
renda_treino.isna().sum()
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_8764\808239420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   renda_treino.tempo_emprego = renda_treino.tempo_emprego.fillna(renda_treino.tempo_emprego.mean())
# Unnamed: 0               0
# data_ref                 0
# id_cliente               0
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# qt_pessoas_residencia    0
# renda                    0
# dtype: int64

# %%
renda_teste.tempo_emprego = renda_teste.tempo_emprego.fillna(renda_teste.tempo_emprego.mean())
renda_teste.isna().sum()
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_8764\2192945132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   renda_teste.tempo_emprego = renda_teste.tempo_emprego.fillna(renda_teste.tempo_emprego.mean())
# Unnamed: 0               0
# data_ref                 0
# id_cliente               0
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# qt_pessoas_residencia    0
# renda                    0
# dtype: int64

# %%
renda_treino = renda_treino.query('renda < 20000')
renda_teste = renda_teste.query('renda < 20000')

# %%
# sns.set_theme(style="white")
corr = renda_treino.corr(numeric_only=True)
mask = np.triu(renda_treino.corr(numeric_only=True))
cmap = sns.color_palette("rocket")

sns.heatmap(corr, 
            mask=mask, 
            cmap=cmap,
            vmax=.7, 
            center=0,
            square=True, 
            linewidths=1, 
            cbar_kws={"shrink": .5}
           )
# Out:
# <Axes: >

# %%
renda_treino.columns
# Out:
# Index(['Unnamed: 0', 'data_ref', 'id_cliente', 'sexo', 'posse_de_veiculo',
#        'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
#        'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego',
#        'qt_pessoas_residencia', 'renda'],
#       dtype='object')

# %%
variaveis = ['sexo', 'posse_de_veiculo',
       'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
       'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego', 'renda']

# %% [markdown]
# ## Etapa 4 Crisp-DM: Modelagem
# Nessa etapa que realizaremos a construção do modelo. Os passos típicos são:
# - Selecionar a técnica de modelagem
# - Desenho do teste
# - Avaliação do modelo

# %% [markdown]
# <span style="color:red">Para a modelagem, foram utilizadas duas técnicas. A primeira de seleção do melhor modelo a partir do treinamento com a combinação de variávies. A combinação foi feita para 1 até 5 variáveis. A segunda técnica foi a de Stepwise para seleção de variáveis.</span>

# %%
reg = smf.ols('renda ~ sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda + educacao + estado_civil + tipo_residencia + idade + tempo_emprego', data = renda_treino).fit()
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.280
# Method:                 Least Squares   F-statistic:                     196.7
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:39:58   Log-Likelihood:            -1.0988e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11564   BIC:                         2.200e+05
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
X = renda_treino.drop(columns=['data_ref', 'id_cliente', 'renda'])
X['posse_de_veiculo'] = X['posse_de_veiculo'].replace(True, 1)
X['posse_de_veiculo'] = X['posse_de_veiculo'].replace(False, 0)
X['posse_de_imovel'] = X['posse_de_imovel'].replace(True, 1)
X['posse_de_imovel'] = X['posse_de_imovel'].replace(False, 0)
X = pd.get_dummies(X)
X.columns = [col.replace(' ', '_') for col in X.columns]
y = renda_treino['renda']

# %%
def processSubset(feature_set):
    # Fit model on feature_set and calculate RSS
    new_X = sm.add_constant(X)  
    feature_set += ("const",)
    model = sm.OLS(y,new_X[list(feature_set)])
    regr = model.fit()
    RSS = ((regr.predict(new_X[list(feature_set)]) - y) ** 2).sum()
    return {"model":regr, "RSS":RSS, "variables":feature_set}

def getBest(k, selecao):
    
    tic = time.time()
    
    results = []
    
    for combo in itertools.combinations(X[selecao].columns, k):
        results.append(processSubset(combo))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['RSS'].argmin()]
    
    toc = time.time()
    print("Processed", models.shape[0], "models on", k, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

# %%
import itertools
import time

models_best = pd.DataFrame(columns=["RSS", "model", "variables"])
selecao = ['posse_de_veiculo', 'posse_de_imovel', 'qtd_filhos',
       'idade', 'tempo_emprego', 'qt_pessoas_residencia', 'sexo_F', 'sexo_M',
       'tipo_renda_Assalariado', 'tipo_renda_Empresário',
       'tipo_renda_Pensionista', 'tipo_renda_Servidor_público',
       'educacao_Primário', 'educacao_Pós_graduação', 'educacao_Secundário',
       'educacao_Superior_completo', 'educacao_Superior_incompleto']

tic = time.time()
for i in range(1, 6):
    models_best.loc[i] = getBest(i, selecao)

toc = time.time()
print("Total elapsed time:", (toc-tic), "seconds.")
models_best.sort_values('RSS')
# Out:
# Processed 17 models on 1 predictors in 0.22524118423461914 seconds.
# Processed 136 models on 2 predictors in 1.6015713214874268 seconds.
# Processed 680 models on 3 predictors in 8.599994421005249 seconds.
# Processed 2380 models on 4 predictors in 34.38308072090149 seconds.
# Processed 6188 models on 5 predictors in 148.35571432113647 seconds.
# Total elapsed time: 236.59002351760864 seconds.
#                    RSS                                              model  \
# 5  117532728814.642395  <statsmodels.regression.linear_model.Regressio...
# 4  117980591253.178467  <statsmodels.regression.linear_model.Regressio...
# 3  118724071692.762512  <statsmodels.regression.linear_model.Regressio...
# 2  119959042956.539337  <statsmodels.regression.linear_model.Regressio...
# 1  144600814371.476135  <statsmodels.regression.linear_model.Regressio...
#
#                                            variables
# 5  (tempo_emprego, sexo_F, tipo_renda_Assalariado...
# ...

# %%
print(models_best.sort_values('RSS').variables[5])
models_best.sort_values('RSS').model[5].summary()
# Out:
# ('tempo_emprego', 'sexo_F', 'tipo_renda_Assalariado', 'tipo_renda_Pensionista', 'educacao_Superior_completo', 'const')
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     887.6
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:43:58   Log-Likelihood:            -1.0991e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11582   BIC:                         2.199e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
formula = f"renda ~ {' + '.join(models_best.sort_values('RSS').variables[5][:-1])}"
reg_models_best = smf.ols(formula, data = pd.concat([X, y], axis=1))
reg_models_best_result = reg_models_best.fit()
reg_models_best_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     887.6
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:43:59   Log-Likelihood:            -1.0991e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11582   BIC:                         2.199e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.05, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded, dtype=np.dtype('float64'))
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.index[new_pval.argmin()]
            included.append(best_feature)
            changed=True
            if verbose:
                 print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        print("#############")
        print(included)
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

variaveis = stepwise_selection(X, y)

print('resulting features:')
print(variaveis)
# Out:
# Add  sexo_F                         with p-value 4.64197e-297
# #############
# ['sexo_F']
# Add  tempo_emprego                  with p-value 0.0
# #############
# ['sexo_F', 'tempo_emprego']
# Add  sexo_M                         with p-value 0.0
# #############
# ['sexo_F', 'tempo_emprego', 'sexo_M']
# Add  tipo_renda_Empresário          with p-value 6.75608e-28
# #############
# ['sexo_F', 'tempo_emprego', 'sexo_M', 'tipo_renda_Empresário']
# Add  educacao_Superior_completo     with p-value 1.46367e-17
# #############
# ['sexo_F', 'tempo_emprego', 'sexo_M', 'tipo_renda_Empresário', 'educacao_Superior_completo']
# Add  tipo_renda_Pensionista         with p-value 1.07403e-10
# #############
# ['sexo_F', 'tempo_emprego', 'sexo_M', 'tipo_renda_Empresário', 'educacao_Superior_completo', 'tipo_renda_Pensionista']
# Add  posse_de_imovel                with p-value 2.47082e-06
# #############
# ...

# %%
variaveis = ['tempo_emprego', 'sexo_M', 'sexo_F', 'tipo_renda_Empresário', 'tipo_renda_Pensionista', 'educacao_Superior_completo', 'idade', 'posse_de_imovel', 'estado_civil_Casado']
" + ".join(variaveis)
# Out:
# 'tempo_emprego + sexo_M + sexo_F + tipo_renda_Empresário + tipo_renda_Pensionista + educacao_Superior_completo + idade + posse_de_imovel + estado_civil_Casado'

# %% [markdown]
# ### Rodando o modelo

# %% [markdown]
# <span style="color:red"> A técnica Stepwise apresentou resultados melhores. Depois foi aplicada uma técnica de otimização 'elastic_net', mas que não apresentou melhorias.</span>

# %%
formula = f"renda ~ {' + '.join(variaveis)}"
reg_stepwise = smf.ols(formula, data = pd.concat([X,y], axis=1))
reg_stepwise_results = reg_stepwise.fit()
reg_stepwise_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     560.2
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:44:03   Log-Likelihood:            -1.0990e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11579   BIC:                         2.199e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
reg1 = reg_models_best.fit_regularized(method = 'elastic_net' 
                         , refit = True
                         , L1_wt = 1
                         , alpha = 0.01)

reg1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     739.7
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:44:04   Log-Likelihood:            -1.0991e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11582   BIC:                         2.199e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
reg2 = reg_stepwise.fit_regularized(method = 'elastic_net' 
                         , refit = True
                         , L1_wt = 1
                         , alpha = 0.01)

reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  renda   R-squared:                       0.279
# Model:                            OLS   Adj. R-squared:                  0.279
# Method:                 Least Squares   F-statistic:                     448.2
# Date:                Fri, 29 Dec 2023   Prob (F-statistic):               0.00
# Time:                        10:44:04   Log-Likelihood:            -1.0990e+05
# No. Observations:               11588   AIC:                         2.198e+05
# Df Residuals:                   11578   BIC:                         2.199e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Etapa 5 Crisp-DM: Avaliação dos resultados

# %% [markdown]
# <span style="color:red">Abaixo estão as avaliações d</span>

# %%
X_teste = renda_teste.drop(columns=['data_ref', 'id_cliente', 'renda'])
X_teste['posse_de_veiculo'] = X_teste['posse_de_veiculo'].replace(True, 1)
X_teste['posse_de_veiculo'] = X_teste['posse_de_veiculo'].replace(False, 0)
X_teste['posse_de_imovel'] = X_teste['posse_de_imovel'].replace(True, 1)
X_teste['posse_de_imovel'] = X_teste['posse_de_imovel'].replace(False, 0)
X_teste = pd.get_dummies(X_teste)
X_teste.columns = [col.replace(' ', '_') for col in X_teste.columns]
y_teste = renda_teste['renda']

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = reg1.predict(pd.concat([X_teste, y_teste], axis=1))

# y_pred
# y_teste

r2 = r2_score(y_teste, y_pred)
mse = mean_squared_error(y_teste, y_pred)
print('R2: {0:.2f}%'.format(r2*100))
print('MSE: {0:.2f}'.format(mse))
# Out:
# R2: 23.88%
# MSE: 10240171.55

# %%
from sklearn.metrics import r2_score, mean_squared_error
y_pred = reg2.predict(pd.concat([X_teste, y_teste], axis=1))

# y_pred
# y_teste

r2 = r2_score(y_teste, y_pred)
mse = mean_squared_error(y_teste, y_pred)
print('R2: {0:.2f}%'.format(r2*100))
print('MSE: {0:.2f}'.format(mse))
# Out:
# R2: 24.38%
# MSE: 10172612.81

# %% [markdown]
# ## Etapa 6 Crisp-DM: Implantação
# Nessa etapa colocamos em uso o modelo desenvolvido, normalmente implementando o modelo desenvolvido em um motor que toma as decisões com algum nível de automação.

# %%
reg2.save("model.pkl")

# %%
from statsmodels.iolib.smpickle import load_pickle
new_model = load_pickle("model.pkl")

# %%
def previsao_de_renda(dados):
    y_pred = new_model.predict(dados)
    print(f"A renda prevista é de {y_pred[0]:,.2f}")

# %%
dados = {
    'tempo_emprego': 2,
    'sexo_M': 0,
    'sexo_F': 1,
    'tipo_renda_Empresário': 0,
    'tipo_renda_Pensionista': 0,
    'educacao_Superior_completo': 0,
    'idade': 20,
    'posse_de_imovel': 0,
    'estado_civil_Casado': 0    
}

previsao_de_renda(dados)
# Out:
# A renda prevista é de 1,506.46
